# %% [markdown]
# # Image as a data

# %% [markdown]
# Import libraries and list the versions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Check libraries

# %%
print('\n'.join(f'{m.__name__} {m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# pandas 1.1.4
# numpy 1.19.2

# %%
# !pip show numpy
# Out:
# Name: numpy
# Version: 1.19.2
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email: None
# License: BSD
# Location: /home/najmeh/anaconda3/envs/deep-learning/lib/python3.7/site-packages
# Requires:
# Required-by: tifffile, scipy, scikit-learn, scikit-image, PyWavelets, pandas, mkl-random, mkl-fft, matplotlib, imageio

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.3.2
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /home/najmeh/anaconda3/envs/deep-learning/lib/python3.7/site-packages
# Requires: numpy, cycler, pyparsing, certifi, kiwisolver, pillow, python-dateutil
# Required-by: scikit-image

# %% [markdown]
# Load an image from image folder and desplay

# %%
img1 = np.array(plt.imread('./image/git.png'))

# display the image
plt.imshow(img1)
plt.show()

# %%
print('Image Dimension is :', img1.shape)
# Out:
# Image Dimension is : (159, 177, 4)

# %% [markdown]
# We have read all the four channels of the image. Namely **Red, Green, Blue and Transparency**.

# %%
print('Given point has three channel RGB =', img1[100,50])
# Out:
# Given point has three channel RGB = [1. 1. 1. 1.]

# %%
print('Image size is :', img2.shape)
# Out:
# Image size is : (425, 640, 3)

# %% [markdown]
# ## modify the color image

# %%
#channel1=R, chanel2=B, channel3=G
img1[:,:,1]=0.2  #channel2 changed to 0
plt.imshow(img1)
plt.show()

# %% [markdown]
# # cropping

# %%
# Load the image
data = np.array(plt.imread('./image/git.png'))


# Set the red channel in this part of the image to 0
data[50:100, 50:100, 0] = 0

# Set the green channel in this part of the image to 255
data[50:100, 50:100, 1] = 0

# Set the blue channel in this part of the image to 0
data[50:100, 50:100, 2] = 0

# Visualize the result
plt.imshow(data)
plt.show()
